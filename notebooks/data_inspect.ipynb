# %%
import pandas as pd

# %%
df = pd.read_csv("../Train_Data_SSD26/train-english.csv")
df.head()
# Out:
#      id                                               text           task1  \
# 0  6095  first happened everyone hating lockdown protes...  Non-Supportive
# 1  9467  fixed chocolate dfly wreck october cytomorphol...  Non-Supportive
# 2  4369                      expect happen jump moving car  Non-Supportive
# 3  8737  muslimemerdear please try get authentic islami...  Non-Supportive
# 4  6193  go back africa blm always said nobody ever say...  Non-Supportive
#
#   task2 task3
# 0    No    No
# 1    No    No
# 2    No    No
# 3    No    No
# 4    No    No

# %%
df["task1"].value_counts()
# Out:
# task1
# Non-Supportive    6203
# Supportive        1795
# Name: count, dtype: int64

# %%
df["task2"].value_counts()
# Out:
# task2
# No            6203
# Group         1450
# Individual     345
# Name: count, dtype: int64

# %%
df["task3"].value_counts()
# Out:
# task3
# No                 6548
# Nation              786
# Other               416
# LGBTQ               123
# Black Community      91
# Women                19
# Religion             15
# Name: count, dtype: int64
